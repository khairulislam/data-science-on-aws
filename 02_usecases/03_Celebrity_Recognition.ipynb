# %% [markdown]
# # Celebrity Recognition using Amazon Rekognition

# %% [markdown]
# This notebook provides a walkthrough of [celebrity recognition API](https://docs.aws.amazon.com/rekognition/latest/dg/celebrities.html) in Amazon Rekognition. You can quickly identify well known people in your video and image libraries to catalog footage and photos for marketing, advertising, and media industry use cases.
#
# * https://docs.aws.amazon.com/rekognition/latest/dg/celebrities.html
# * https://docs.aws.amazon.com/rekognition/latest/dg/API_RecognizeCelebrities.html
# * https://docs.aws.amazon.com/rekognition/latest/dg/API_StartCelebrityRecognition.html
# * https://docs.aws.amazon.com/rekognition/latest/dg/API_GetCelebrityRecognition.html

# %% [markdown]
# # Setup

# %%
import boto3
from IPython.display import HTML, display, Image as IImage
from PIL import Image, ImageDraw, ImageFont
import time
import os

# %%
import sagemaker
import boto3

sagemaker_session = sagemaker.Session()
role = sagemaker.get_execution_role()
bucket = sagemaker_session.default_bucket()
region = boto3.Session().region_name

# %%
rekognition = boto3.client("rekognition")
s3 = boto3.client("s3")
# Out:
# /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.7/site-packages/boto3/compat.py:82: PythonDeprecationWarning: Boto3 will no longer support Python 3.7 starting December 13, 2023. To continue receiving service updates, bug fixes, and security updates please upgrade to Python 3.8 or later. More information can be found here: https://aws.amazon.com/blogs/developer/python-support-policy-updates-for-aws-sdks-and-tools/
#   warnings.warn(warning, PythonDeprecationWarning)

# %%
# !mkdir -p ./tmp
temp_folder = "tmp/"

# %% [markdown]
# # Recognize Celebrities in Images

# %%
imageName = "content-moderation/media/GrandTourjc.png"

# %%
display(IImage(url=s3.generate_presigned_url("get_object", Params={"Bucket": bucket, "Key": imageName})))
# Out:
# <img src="https://sagemaker-us-east-1-211125778552.s3.amazonaws.com/content-moderation/media/GrandTourjc.png?AWSAccessKeyId=ASIATCKATXB4OG52ALMO&Signature=iGISMnoMaMpv2zLOFI9D%2BrthvDs%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENf%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJGMEQCIBP15YhhVvceMb0ionq14SLdbpF0XICmMO9zOm7x80UeAiAU5LFqunjiVnJV2PmxXVF6MdDR7nxpc6pM4DGnKQZ1wiqrAwiw%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDIxMTEyNTc3ODU1MiIMxLWW8ae96EmN361BKv8C%2FqXQErB%2FdyB%2FUl0SJ6JCvDUzsMVII6VZ3Rb77eM5m2ADAW%2FdDvJBaxM4IcI468bxdfOQtrxbEFcfysIuisme%2FYNlXEuzhzK8q%2FPMtgH9XfKp3ScA4sAC64G6JvLs3%2Bqge1qjTcinAtc8zEjqGodueoIOKLmHJCWLqZAKG70VRLsZJe%2FrLmY3UaJ7lOb3uyxyjxvoBGDQDmbd4yO6FjF%2FTRkiBUlF%2FjOBH8aVCOLCN17SMtqw2LbLtk79R4Nujvp%2FQbv540EqEKk8Uuzt9XUykCPAemzEPqvvAzBQ1WxOTh2ObVq8e5fIJb%2F5WTRv9OkVSSQ6cyJl3Wv3%2BxxuD8wf7KcgcBbxILpZaKIVqY7f4psgJokZEqZkoFoVBFHGxOJtPzrU1eAIU02tWQlkJm0%2BhBKDwvfnAKOtaqbO7Nl1KSZpGaDGx0tKWBhEV5r82NQ6KnychC8SeCb%2BW7DJSuTNkBjJHSqGtw4QI79yMd6lulVt%2BnRT5sCxhKqupzDUojcwyKy6rgY6nwHW34PyBOzLtiGggHBq2tXBx4CZbWpaGRd3pYc3iTGsitj8MdmJy8%2BS1u7XAivGbwSLYVj9%2BnQmWutsomZD6NyGOAtIU4W8gje%2FjSzFaczkNzZ%2B%2BB8kQZKIcWws7ZShFrG%2FVvqluJWIBDmK8irkNo51lVtNq2XQ51f4UQx01AsxOV%2FDLShGqMjnIx05GOdt9jHdjkvUEuLSk%2FAsWT4LATE%3D&Expires=1708042984"/>

# %% [markdown]
# # Call Amazon Rekognition to recognize celebrities in the image
# https://docs.aws.amazon.com/rekognition/latest/dg/API_RecognizeCelebrities.html

# %%
recognizeCelebritiesResponse = rekognition.recognize_celebrities(
    Image={
        "S3Object": {
            "Bucket": bucket,
            "Name": imageName,
        }
    }
)

# %% [markdown]
# # Review JSON response returned by Rekognition Celebrity Recognition API
# In the JSON response below, you will see CelebrityFaces which contains information about recognized celebrities.
#
# For each recognized celebrity, you will see information like Name, Id, Urls and additional information about their facial attributes.

# %%
display(recognizeCelebritiesResponse)
# Out:
# {'CelebrityFaces': [{'Urls': ['www.wikidata.org/wiki/Q216160',
#     'www.imdb.com/name/nm0165087'],
#    'Name': 'Jeremy Clarkson',
#    'Id': '2mW0ey5n',
#    'Face': {'BoundingBox': {'Width': 0.17245951294898987,
#      'Height': 0.5064846277236938,
#      'Left': 0.20956459641456604,
#      'Top': 0.1436367630958557},
#     'Confidence': 99.9980239868164,
#     'Landmarks': [{'Type': 'nose',
#       'X': 0.37251022458076477,
#       'Y': 0.43928447365760803},
#      {'Type': 'eyeLeft', 'X': 0.3125169277191162, 'Y': 0.33740484714508057},
#      {'Type': 'mouthLeft', 'X': 0.30566859245300293, 'Y': 0.5114881992340088},
#      {'Type': 'mouthRight', 'X': 0.34567299485206604, 'Y': 0.529137909412384},
#      {'Type': 'eyeRight', 'X': 0.3611130118370056, 'Y': 0.36034104228019714}],
#     'Pose': {'Roll': 9.265666007995605,
#      'Yaw': 47.319950103759766,
#      'Pitch': 2.151289701461792},
#     'Quality': {'Brightness': 65.40837860107422,
#      'Sharpness': 83.14741516113281},
#     'Emotions': [{'Type': 'CALM', 'Confidence': 42.14436340332031},
#      {'Type': 'SAD', 'Confidence': 41.34675979614258},
#      {'Type': 'CONFUSED', 'Confidence': 13.755570411682129},
#      {'Type': 'ANGRY', 'Confidence': 1.9192391633987427},
#      {'Type': 'SURPRISED', 'Confidence': 0.378974050283432},
#      {'Type': 'DISGUSTED', 'Confidence': 0.34111109375953674},
#      {'Type': 'HAPPY', 'Confidence': 0.059661105275154114},
#      {'Type': 'FEAR', 'Confidence': 0.0543208085000515}],
#     'Smile': {'Value': False, 'Confidence': 99.54156494140625}},
#    'MatchConfidence': 99.74726867675781,
#    'KnownGender': {'Type': 'Male'}}],
#  'UnrecognizedFaces': [],
#  'ResponseMetadata': {'RequestId': '3b1b1e25-3cae-425e-ad59-03ec9f5cb0c9',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '3b1b1e25-3cae-425e-ad59-03ec9f5cb0c9',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '1358',
#    'date': 'Thu, 15 Feb 2024 23:23:05 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# # Show Image with Bounding Boxes Around Recognized Celebrities

# %%
def drawBoundingBoxes(sourceImage, boxes):
    # blue, green, red, grey
    colors = ((255, 255, 255), (255, 255, 255), (76, 182, 252), (52, 194, 123))

    # Download image locally
    imageLocation = temp_folder + os.path.basename(sourceImage)
    s3.download_file(bucket, sourceImage, imageLocation)

    # Draws BB on Image
    bbImage = Image.open(imageLocation)
    draw = ImageDraw.Draw(bbImage)
    width, height = bbImage.size
    col = 0
    maxcol = len(colors)
    line = 3
    for box in boxes:
        x1 = int(box[1]["Left"] * width)
        y1 = int(box[1]["Top"] * height)
        x2 = int(box[1]["Left"] * width + box[1]["Width"] * width)
        y2 = int(box[1]["Top"] * height + box[1]["Height"] * height)

        draw.text((x1, y1), box[0], colors[col])
        for l in range(line):
            draw.rectangle((x1 - l, y1 - l, x2 + l, y2 + l), outline=colors[col])
        col = (col + 1) % maxcol

    imageFormat = "PNG"
    ext = sourceImage.lower()
    if ext.endswith("jpg") or ext.endswith("jpeg"):
        imageFormat = "JPEG"

    bbImage.save(imageLocation, format=imageFormat)

    display(bbImage)

# %%
boxes = []
celebrities = recognizeCelebritiesResponse["CelebrityFaces"]
for celebrity in celebrities:
    boxes.append((celebrity["Name"], celebrity["Face"]["BoundingBox"]))

drawBoundingBoxes(imageName, boxes)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2556x1440>

# %% [markdown]
# # Recognize Celebrities in Videos
#  Celebrity recognition in video is an async operation.
#  https://docs.aws.amazon.com/rekognition/latest/dg/API_StartCelebrityRecognition.html
#  - We first start celebrity recognition job which returns a Job Id.
#  - We can then call `get_celebrity_recognition` to get the job status and after job is complete, we can get celebrity metadata.
#  - In production use cases, you would usually use StepFucntion or SNS topic to get notified when job is complete.

# %%
videoName = "content-moderation/media/GrandTour720.mp4"
strDetail = "Celebrites detected in video<br>=======================================<br>"
strOverall = "Celebrities in the overall video:<br>=======================================<br>"

# %%
s3FilePrefix = "https://s3.amazonaws.com"
if not region == "us-east-1":
    s3FilePrefix = "https://s3-{}.amazonaws.com".format(region)

s3VideoUrl = "{0}/{1}/{2}".format(s3FilePrefix, bucket, videoName)

videoTag = "<video controls='controls' autoplay width='640' height='360' name='Video' src='{0}'></video>".format(
    s3VideoUrl
)

videoui = "<table><tr><td style='vertical-align: top'>{}</td></tr><tr><td>{}</td></tr></table>".format(
    videoTag, strDetail
)

display(HTML(videoui))
# Out:
# <table><tr><td style='vertical-align: top'><video controls='controls' autoplay width='640' height='360' name='Video' src='https://s3.amazonaws.com/sagemaker-us-east-1-211125778552/content-moderation/media/GrandTour720.mp4'></video></td></tr><tr><td>Celebrites detected in video<br>=======================================<br></td></tr></table>

# %% [markdown]
# # Call Rekognition to Start a Job for Celebrity Rekognition

# %%
startCelebrityRekognition = rekognition.start_celebrity_recognition(
    Video={
        "S3Object": {
            "Bucket": bucket,
            "Name": videoName,
        }
    },
)

celebrityJobId = startCelebrityRekognition["JobId"]
display("Job Id: {0}".format(celebrityJobId))
# Out:
# 'Job Id: 86fab6f99f35bcdf7857dc393a4e25f1a27acce91ca0df9fdf86c35ac6ca6143'

# %% [markdown]
# # Wait for Celebrity Rekognition Job to Complete
# * In production use cases, you would usually use StepFucntion or SNS topic to get notified when job is complete.

# %%
# %%time

getCelebrityRecognition = rekognition.get_celebrity_recognition(JobId=celebrityJobId, SortBy="TIMESTAMP")

while getCelebrityRecognition["JobStatus"] == "IN_PROGRESS":
    time.sleep(5)
    print(".", end="")

    getCelebrityRecognition = rekognition.get_celebrity_recognition(JobId=celebrityJobId, SortBy="TIMESTAMP")

display(getCelebrityRecognition["JobStatus"])
# Out:
# .......
# 'SUCCEEDED'
# CPU times: user 33.9 ms, sys: 4.15 ms, total: 38.1 ms
# Wall time: 35.2 s

# %% [markdown]
# # Review JSON response returned by Rekognition Celebrity Recognition API
# In the JSON response below, you will see list Celebrities which contains information about recognized celebrities.
#
# For each recognized celebrity, you will see information like Timestamp, Name, Id, Urls
#  and additional information about their facial attributes.

# %%
display(getCelebrityRecognition)
# Out:
# {'JobStatus': 'SUCCEEDED',
#  'VideoMetadata': {'Codec': 'h264',
#   'DurationMillis': 15015,
#   'Format': 'QuickTime / MOV',
#   'FrameRate': 23.976024627685547,
#   'FrameHeight': 720,
#   'FrameWidth': 1280,
#   'ColorRange': 'LIMITED'},
#  'Celebrities': [{'Timestamp': 2460,
#    'Celebrity': {'Urls': ['www.wikidata.org/wiki/Q216160',
#      'www.imdb.com/name/nm0165087'],
#     'Name': 'Jeremy Clarkson',
#     'Id': '2mW0ey5n',
#     'Confidence': 99.83981323242188,
#     'Face': {'BoundingBox': {'Width': 0.17029087245464325,
#       'Height': 0.5028613805770874,
#       'Left': 0.21125762164592743,
#       'Top': 0.1456305980682373},
#      'Landmarks': [{'Type': 'eyeLeft',
#        'X': 0.31368258595466614,
#        'Y': 0.336062490940094},
#       {'Type': 'eyeRight', 'X': 0.36271932721138, 'Y': 0.36189624667167664},
#       {'Type': 'mouthLeft', 'X': 0.3011455237865448, 'Y': 0.5094919204711914},
#       {'Type': 'mouthRight', 'X': 0.3415478467941284, 'Y': 0.529556155204773},
#       {'Type': 'nose', 'X': 0.36966222524642944, 'Y': 0.4396417737007141}],
#      'Pose': {'Roll': 11.551424026489258,
#       'Yaw': 47.119285583496094,
#       'Pitch': 3.028489112854004},
#      'Quality': {'Brightness': 57.70246887207031,
#       'Sharpness': 83.14741516113281},
#      'Confidence': 99.99826049804688},
#     'KnownGender': {'Type': 'Male'}}},
#   {'Timestamp': 2961,
#    'Celebrity': {'Urls': ['www.wikidata.org/wiki/Q216160',
#      'www.imdb.com/name/nm0165087'],
#     'Name': 'Jeremy Clarkson',
#     'Id': '2mW0ey5n',
#     'Confidence': 99.88538360595703,
#     'Face': {'BoundingBox': {'Width': 0.1718916893005371,
#       'Height': 0.5093004107475281,
#       'Left': 0.20877251029014587,
#       'Top': 0.14642900228500366},
#      'Landmarks': [{'Type': 'eyeLeft',
#        'X': 0.31213250756263733,
#        'Y': 0.33278390765190125},
#       {'Type': 'eyeRight', 'X': 0.3624865710735321, 'Y': 0.35994359850883484},
#       {'Type': 'mouthLeft', 'X': 0.30089834332466125, 'Y': 0.512268602848053},
#       {'Type': 'mouthRight', 'X': 0.3424169421195984, 'Y': 0.5335293412208557},
#       {'Type': 'nose', 'X': 0.36951491236686707, 'Y': 0.4383004605770111}],
#      'Pose': {'Roll': 12.31001091003418,
#       'Yaw': 47.0086555480957,
#       'Pitch': 3.3798108100891113},
#      'Quality': {'Brightness': 57.28572463989258,
#       'Sharpness': 86.86019134521484},
#      'Confidence': 99.99788665771484},
#     'KnownGender': {'Type': 'Male'}}},
#   {'Timestamp': 3461,
#    'Celebrity': {'Urls': ['www.wikidata.org/wiki/Q216160',
#      'www.imdb.com/name/nm0165087'],
#     'Name': 'Jeremy Clarkson',
#     'Id': '2mW0ey5n',
#     'Confidence': 99.57072448730469,
#     'Face': {'BoundingBox': {'Width': 0.17130959033966064,
#       'Height': 0.49779853224754333,
#       'Left': 0.20976383984088898,
#       'Top': 0.1482691913843155},
#      'Landmarks': [{'Type': 'eyeLeft',
#        'X': 0.3114929497241974,
#        'Y': 0.33515894412994385},
#       {'Type': 'eyeRight', 'X': 0.36204057931900024, 'Y': 0.3617207407951355},
#       {'Type': 'mouthLeft', 'X': 0.301462322473526, 'Y': 0.5104262232780457},
#       {'Type': 'mouthRight',
#        'X': 0.34310486912727356,
#        'Y': 0.5311668515205383},
#       {'Type': 'nose', 'X': 0.3687562346458435, 'Y': 0.437017560005188}],
#      'Pose': {'Roll': 10.653351783752441,
#       'Yaw': 46.105621337890625,
#       'Pitch': 3.401660203933716},
#      'Quality': {'Brightness': 57.49126052856445,
#       'Sharpness': 86.86019134521484},
#      'Confidence': 99.9984359741211},
#     'KnownGender': {'Type': 'Male'}}},
#   {'Timestamp': 3962,
#    'Celebrity': {'Urls': ['www.wikidata.org/wiki/Q216160',
#      'www.imdb.com/name/nm0165087'],
#     'Name': 'Jeremy Clarkson',
#     'Id': '2mW0ey5n',
#     'Confidence': 99.7980728149414,
#     'Face': {'BoundingBox': {'Width': 0.1675701141357422,
#       'Height': 0.5114369988441467,
#       'Left': 0.2178453952074051,
#       'Top': 0.14504913985729218},
#      'Landmarks': [{'Type': 'eyeLeft',
#        'X': 0.3232711851596832,
#        'Y': 0.3369740843772888},
#       {'Type': 'eyeRight', 'X': 0.36926352977752686, 'Y': 0.3588728606700897},
#       {'Type': 'mouthLeft', 'X': 0.31536662578582764, 'Y': 0.515566349029541},
#       {'Type': 'mouthRight', 'X': 0.3531479835510254, 'Y': 0.5323800444602966},
#       {'Type': 'nose', 'X': 0.3816605806350708, 'Y': 0.4373253285884857}],
#      'Pose': {'Roll': 9.046212196350098,
#       'Yaw': 49.64378356933594,
#       'Pitch': 2.1073250770568848},
#      'Quality': {'Brightness': 57.152713775634766,
#       'Sharpness': 86.86019134521484},
#      'Confidence': 99.99543762207031},
#     'KnownGender': {'Type': 'Male'}}},
#   {'Timestamp': 4462,
#    'Celebrity': {'Urls': ['www.wikidata.org/wiki/Q216160',
#      'www.imdb.com/name/nm0165087'],
#     'Name': 'Jeremy Clarkson',
#     'Id': '2mW0ey5n',
#     'Confidence': 99.45638275146484,
#     'Face': {'BoundingBox': {'Width': 0.17613652348518372,
#       'Height': 0.5195003747940063,
#       'Left': 0.2298092097043991,
#       'Top': 0.17187188565731049},
#      'Landmarks': [{'Type': 'eyeLeft',
#        'X': 0.34136468172073364,
#        'Y': 0.36931657791137695},
#       {'Type': 'eyeRight', 'X': 0.3877391815185547, 'Y': 0.3927842080593109},
#       {'Type': 'mouthLeft', 'X': 0.3250402808189392, 'Y': 0.5452241897583008},
#       {'Type': 'mouthRight', 'X': 0.3633252680301666, 'Y': 0.5632531642913818},
#       {'Type': 'nose', 'X': 0.39571553468704224, 'Y': 0.479526549577713}],
#      'Pose': {'Roll': 12.791102409362793,
#       'Yaw': 50.884578704833984,
#       'Pitch': 0.11408951133489609},
#      'Quality': {'Brightness': 58.62116241455078,
#       'Sharpness': 86.86019134521484},
#      'Confidence': 99.99848937988281},
#     'KnownGender': {'Type': 'Male'}}},
#   {'Timestamp': 4963,
#    'Celebrity': {'Urls': ['www.wikidata.org/wiki/Q216160',
#      'www.imdb.com/name/nm0165087'],
#     'Name': 'Jeremy Clarkson',
#     'Id': '2mW0ey5n',
#     'Confidence': 99.46903228759766,
#     'Face': {'BoundingBox': {'Width': 0.17268919944763184,
#       'Height': 0.5184248089790344,
#       'Left': 0.23010535538196564,
#       'Top': 0.1580791026353836},
#      'Landmarks': [{'Type': 'eyeLeft',
#        'X': 0.3415907919406891,
#        'Y': 0.357318252325058},
#       {'Type': 'eyeRight', 'X': 0.3846561312675476, 'Y': 0.3794592618942261},
#       {'Type': 'mouthLeft', 'X': 0.32623687386512756, 'Y': 0.5314548015594482},
#       {'Type': 'mouthRight', 'X': 0.36165839433670044, 'Y': 0.548248827457428},
#       {'Type': 'nose', 'X': 0.3967772424221039, 'Y': 0.46405935287475586}],
#      'Pose': {'Roll': 10.616299629211426,
#       'Yaw': 53.464412689208984,
#       'Pitch': -0.21046528220176697},
#      'Quality': {'Brightness': 60.542415618896484,
#       'Sharpness': 83.14741516113281},
#      'Confidence': 99.99925231933594},
#     'KnownGender': {'Type': 'Male'}}},
#   {'Timestamp': 7465,
#    'Celebrity': {'Urls': ['www.wikidata.org/wiki/Q216160',
#      'www.imdb.com/name/nm0165087'],
#     'Name': 'Jeremy Clarkson',
#     'Id': '2mW0ey5n',
#     'Confidence': 99.0966796875,
#     'Face': {'BoundingBox': {'Width': 0.16803507506847382,
#       'Height': 0.5061505436897278,
#       'Left': 0.21110954880714417,
#       'Top': 0.1284198760986328},
#      'Landmarks': [{'Type': 'eyeLeft',
#        'X': 0.31108492612838745,
#        'Y': 0.3186171054840088},
#       {'Type': 'eyeRight', 'X': 0.360607773065567, 'Y': 0.3445999324321747},
#       {'Type': 'mouthLeft', 'X': 0.30675551295280457, 'Y': 0.5011298060417175},
#       {'Type': 'mouthRight',
#        'X': 0.34741032123565674,
#        'Y': 0.5214062333106995},
#       {'Type': 'nose', 'X': 0.3719888925552368, 'Y': 0.41925713419914246}],
#      'Pose': {'Roll': 8.82563304901123,
#       'Yaw': 48.58136749267578,
#       'Pitch': 4.220628261566162},
#      'Quality': {'Brightness': 60.43751907348633,
#       'Sharpness': 86.86019134521484},
#      'Confidence': 99.99876403808594},
#     'KnownGender': {'Type': 'Male'}}},
#   {'Timestamp': 7966,
#    'Celebrity': {'Urls': ['www.wikidata.org/wiki/Q216160',
#      'www.imdb.com/name/nm0165087'],
#     'Name': 'Jeremy Clarkson',
#     'Id': '2mW0ey5n',
#     'Confidence': 99.94096374511719,
#     'Face': {'BoundingBox': {'Width': 0.17703565955162048,
#       'Height': 0.5151464343070984,
#       'Left': 0.19434738159179688,
#       'Top': 0.14060470461845398},
#      'Landmarks': [{'Type': 'eyeLeft',
#        'X': 0.28196555376052856,
#        'Y': 0.31943872570991516},
#       {'Type': 'eyeRight', 'X': 0.3481965661048889, 'Y': 0.3424513339996338},
#       {'Type': 'mouthLeft', 'X': 0.2776415944099426, 'Y': 0.5041181445121765},
#       {'Type': 'mouthRight',
#        'X': 0.33259445428848267,
#        'Y': 0.5223042964935303},
#       {'Type': 'nose', 'X': 0.3429344892501831, 'Y': 0.422566682100296}],
#      'Pose': {'Roll': 10.43117904663086,
#       'Yaw': 32.56325912475586,
#       'Pitch': 6.103848934173584},
#      'Quality': {'Brightness': 59.91789245605469,
#       'Sharpness': 83.14741516113281},
#      'Confidence': 99.99927520751953},
#     'KnownGender': {'Type': 'Male'}}},
#   {'Timestamp': 8466,
#    'Celebrity': {'Urls': ['www.wikidata.org/wiki/Q216160',
#      'www.imdb.com/name/nm0165087'],
#     'Name': 'Jeremy Clarkson',
#     'Id': '2mW0ey5n',
#     'Confidence': 99.93047332763672,
#     'Face': {'BoundingBox': {'Width': 0.17848177254199982,
#       'Height': 0.5191432237625122,
#       'Left': 0.19458207488059998,
#       'Top': 0.14913564920425415},
#      'Landmarks': [{'Type': 'eyeLeft',
#        'X': 0.28254157304763794,
#        'Y': 0.32395240664482117},
#       {'Type': 'eyeRight', 'X': 0.34952715039253235, 'Y': 0.34950289130210876},
#       {'Type': 'mouthLeft', 'X': 0.2729671597480774, 'Y': 0.5081258416175842},
#       {'Type': 'mouthRight',
#        'X': 0.32861974835395813,
#        'Y': 0.5284315347671509},
#       {'Type': 'nose', 'X': 0.3405120372772217, 'Y': 0.4294167757034302}],
#      'Pose': {'Roll': 11.707164764404297,
#       'Yaw': 31.159130096435547,
#       'Pitch': 5.762110233306885},
#      'Quality': {'Brightness': 59.819793701171875,
#       'Sharpness': 86.86019134521484},
#      'Confidence': 99.99938201904297},
#     'KnownGender': {'Type': 'Male'}}},
#   {'Timestamp': 8967,
#    'Celebrity': {'Urls': ['www.wikidata.org/wiki/Q216160',
#      'www.imdb.com/name/nm0165087'],
#     'Name': 'Jeremy Clarkson',
#     'Id': '2mW0ey5n',
#     'Confidence': 99.91831970214844,
#     'Face': {'BoundingBox': {'Width': 0.17679154872894287,
#       'Height': 0.5129930973052979,
#       'Left': 0.2000545710325241,
#       'Top': 0.14662796258926392},
#      'Landmarks': [{'Type': 'eyeLeft',
#        'X': 0.29202818870544434,
#        'Y': 0.3270570933818817},
#       {'Type': 'eyeRight', 'X': 0.3561995029449463, 'Y': 0.35278767347335815},
#       {'Type': 'mouthLeft', 'X': 0.2824455499649048, 'Y': 0.5095658898353577},
#       {'Type': 'mouthRight',
#        'X': 0.33569473028182983,
#        'Y': 0.5299250483512878},
#       {'Type': 'nose', 'X': 0.3505082130432129, 'Y': 0.43379685282707214}],
#      'Pose': {'Roll': 12.176454544067383,
#       'Yaw': 34.448299407958984,
#       'Pitch': 5.0205888748168945},
#      'Quality': {'Brightness': 59.98107147216797,
#       'Sharpness': 83.14741516113281},
#      'Confidence': 99.99934387207031},
#     'KnownGender': {'Type': 'Male'}}},
#   {'Timestamp': 9467,
#    'Celebrity': {'Urls': ['www.wikidata.org/wiki/Q216160',
#      'www.imdb.com/name/nm0165087'],
#     'Name': 'Jeremy Clarkson',
#     'Id': '2mW0ey5n',
#     'Confidence': 99.92138671875,
#     'Face': {'BoundingBox': {'Width': 0.17598779499530792,
#       'Height': 0.5024315118789673,
#       'Left': 0.203750878572464,
#       'Top': 0.14599505066871643},
#      'Landmarks': [{'Type': 'eyeLeft',
#        'X': 0.29809659719467163,
#        'Y': 0.331291526556015},
#       {'Type': 'eyeRight', 'X': 0.3603081703186035, 'Y': 0.35750702023506165},
#       {'Type': 'mouthLeft', 'X': 0.28781911730766296, 'Y': 0.5094912052154541},
#       {'Type': 'mouthRight',
#        'X': 0.33936548233032227,
#        'Y': 0.5301123857498169},
#       {'Type': 'nose', 'X': 0.35655149817466736, 'Y': 0.4362896680831909}],
#      'Pose': {'Roll': 12.284502029418945,
#       'Yaw': 36.581398010253906,
#       'Pitch': 4.55908203125},
#      'Quality': {'Brightness': 59.61480712890625,
#       'Sharpness': 83.14741516113281},
#      'Confidence': 99.99891662597656},
#     'KnownGender': {'Type': 'Male'}}},
#   {'Timestamp': 13471,
#    'Celebrity': {'Urls': ['www.wikidata.org/wiki/Q297265',
#      'www.imdb.com/name/nm1414369'],
#     'Name': 'Richard Hammond',
#     'Id': '4TK3NJ',
#     'Confidence': 90.87826538085938,
#     'Face': {'BoundingBox': {'Width': 0.15314407646656036,
#       'Height': 0.37242287397384644,
#       'Left': 0.20204882323741913,
#       'Top': 0.24771031737327576},
#      'Landmarks': [{'Type': 'eyeLeft',
#        'X': 0.29141995310783386,
#        'Y': 0.39572837948799133},
#       {'Type': 'eyeRight', 'X': 0.3311780095100403, 'Y': 0.40025079250335693},
#       {'Type': 'mouthLeft', 'X': 0.3036328852176666, 'Y': 0.5285977125167847},
#       {'Type': 'mouthRight', 'X': 0.3361796438694, 'Y': 0.5311613082885742},
#       {'Type': 'nose', 'X': 0.3518582582473755, 'Y': 0.4518255591392517}],
#      'Pose': {'Roll': -2.1000704765319824,
#       'Yaw': 51.43067169189453,
#       'Pitch': 1.8153221607208252},
#      'Quality': {'Brightness': 68.33491516113281,
#       'Sharpness': 86.86019134521484},
#      'Confidence': 99.99845886230469},
#     'KnownGender': {'Type': 'Male'}}},
#   {'Timestamp': 13972,
#    'Celebrity': {'Urls': ['www.wikidata.org/wiki/Q297265',
#      'www.imdb.com/name/nm1414369'],
#     'Name': 'Richard Hammond',
#     'Id': '4TK3NJ',
#     'Confidence': 99.23809814453125,
#     'Face': {'BoundingBox': {'Width': 0.1611754596233368,
#       'Height': 0.4046785235404968,
#       'Left': 0.19166199862957,
#       'Top': 0.2537112832069397},
#      'Landmarks': [{'Type': 'eyeLeft',
#        'X': 0.2630210220813751,
#        'Y': 0.40978771448135376},
#       {'Type': 'eyeRight', 'X': 0.3259841799736023, 'Y': 0.4129856824874878},
#       {'Type': 'mouthLeft', 'X': 0.2678384780883789, 'Y': 0.5519900321960449},
#       {'Type': 'mouthRight', 'X': 0.3202531933784485, 'Y': 0.5539053082466125},
#       {'Type': 'nose', 'X': 0.31657713651657104, 'Y': 0.48413968086242676}],
#      'Pose': {'Roll': 1.2731306552886963,
#       'Yaw': 25.590656280517578,
#       'Pitch': 0.08607363700866699},
#      'Quality': {'Brightness': 61.808406829833984,
#       'Sharpness': 73.32209777832031},
#      'Confidence': 99.99878692626953},
#     'KnownGender': {'Type': 'Male'}}},
#   {'Timestamp': 14472,
#    'Celebrity': {'Urls': ['www.wikidata.org/wiki/Q297265',
#      'www.imdb.com/name/nm1414369'],
#     'Name': 'Richard Hammond',
#     'Id': '4TK3NJ',
#     'Confidence': 99.48643493652344,
#     'Face': {'BoundingBox': {'Width': 0.15452437102794647,
#       'Height': 0.39473044872283936,
#       'Left': 0.18437866866588593,
#       'Top': 0.2472517043352127},
#      'Landmarks': [{'Type': 'eyeLeft',
#        'X': 0.25271114706993103,
#        'Y': 0.39818334579467773},
#       {'Type': 'eyeRight', 'X': 0.3164477050304413, 'Y': 0.3952106833457947},
#       {'Type': 'mouthLeft', 'X': 0.2618653178215027, 'Y': 0.5351470708847046},
#       {'Type': 'mouthRight',
#        'X': 0.31499963998794556,
#        'Y': 0.5319546461105347},
#       {'Type': 'nose', 'X': 0.30907267332077026, 'Y': 0.4649598002433777}],
#      'Pose': {'Roll': -1.2065037488937378,
#       'Yaw': 24.734804153442383,
#       'Pitch': 1.0755467414855957},
#      'Quality': {'Brightness': 61.67548370361328,
#       'Sharpness': 83.14741516113281},
#      'Confidence': 99.99785614013672},
#     'KnownGender': {'Type': 'Male'}}},
#   {'Timestamp': 14973,
#    'Celebrity': {'Urls': ['www.wikidata.org/wiki/Q297265',
#      'www.imdb.com/name/nm1414369'],
#     'Name': 'Richard Hammond',
#     'Id': '4TK3NJ',
#     'Confidence': 99.57633209228516,
#     'Face': {'BoundingBox': {'Width': 0.15230926871299744,
#       'Height': 0.3853296935558319,
#       'Left': 0.18286442756652832,
#       'Top': 0.25104138255119324},
#      'Landmarks': [{'Type': 'eyeLeft',
#        'X': 0.254037469625473,
#        'Y': 0.40143120288848877},
#       {'Type': 'eyeRight', 'X': 0.3152305483818054, 'Y': 0.39836451411247253},
#       {'Type': 'mouthLeft', 'X': 0.26361700892448425, 'Y': 0.5420843958854675},
#       {'Type': 'mouthRight', 'X': 0.3145677149295807, 'Y': 0.5387551188468933},
#       {'Type': 'nose', 'X': 0.31066909432411194, 'Y': 0.47016775608062744}],
#      'Pose': {'Roll': -1.8632698059082031,
#       'Yaw': 28.00977325439453,
#       'Pitch': -0.5318065285682678},
#      'Quality': {'Brightness': 62.55012893676758,
#       'Sharpness': 86.86019134521484},
#      'Confidence': 99.99879455566406},
#     'KnownGender': {'Type': 'Male'}}}],
#  'JobId': '86fab6f99f35bcdf7857dc393a4e25f1a27acce91ca0df9fdf86c35ac6ca6143',
#  'Video': {'S3Object': {'Bucket': 'sagemaker-us-east-1-211125778552',
#    'Name': 'content-moderation/media/GrandTour720.mp4'}},
#  'ResponseMetadata': {'RequestId': '6acfb04d-f52b-4107-b263-a4f32438c0d6',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '6acfb04d-f52b-4107-b263-a4f32438c0d6',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '13502',
#    'date': 'Thu, 15 Feb 2024 23:23:43 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# # Display Names of Recognized Celebrities in the Video
# Display timestamps and celebrites detected at that time.

# %%
theCelebs = {}

# Celebrities detected in each frame
for celebrity in getCelebrityRecognition["Celebrities"]:
    if "Celebrity" in celebrity:
        cconfidence = celebrity["Celebrity"]["Confidence"]
        if cconfidence > 95:
            ts = celebrity["Timestamp"]
            cname = celebrity["Celebrity"]["Name"]
            strDetail = strDetail + "At {} ms: {} (Confidence: {})<br>".format(ts, cname, round(cconfidence, 2))
            if not cname in theCelebs:
                theCelebs[cname] = cname


# Unique faces detected in video
for theCeleb in theCelebs:
    strOverall = strOverall + "Name: {}<br>".format(theCeleb)

# Display results
display(HTML(strOverall))
# Out:
# Celebrities in the overall video:<br>=======================================<br>Name: Jeremy Clarkson<br>Name: Richard Hammond<br>

# %% [markdown]
# # Detect Non-Celebrities
# Now let us try an image with non-celebrities in the image.

# %%
customCelebrityImageName = "content-moderation/media/chris-antje.png"

# %%
display(
    IImage(url=s3.generate_presigned_url("get_object", Params={"Bucket": bucket, "Key": customCelebrityImageName}))
)
# Out:
# <img src="https://sagemaker-us-east-1-211125778552.s3.amazonaws.com/content-moderation/media/chris-antje.png?AWSAccessKeyId=ASIATCKATXB4OG52ALMO&Signature=57HSMFLRMLCKGoDVkPARF9qDheA%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENf%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJGMEQCIBP15YhhVvceMb0ionq14SLdbpF0XICmMO9zOm7x80UeAiAU5LFqunjiVnJV2PmxXVF6MdDR7nxpc6pM4DGnKQZ1wiqrAwiw%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDIxMTEyNTc3ODU1MiIMxLWW8ae96EmN361BKv8C%2FqXQErB%2FdyB%2FUl0SJ6JCvDUzsMVII6VZ3Rb77eM5m2ADAW%2FdDvJBaxM4IcI468bxdfOQtrxbEFcfysIuisme%2FYNlXEuzhzK8q%2FPMtgH9XfKp3ScA4sAC64G6JvLs3%2Bqge1qjTcinAtc8zEjqGodueoIOKLmHJCWLqZAKG70VRLsZJe%2FrLmY3UaJ7lOb3uyxyjxvoBGDQDmbd4yO6FjF%2FTRkiBUlF%2FjOBH8aVCOLCN17SMtqw2LbLtk79R4Nujvp%2FQbv540EqEKk8Uuzt9XUykCPAemzEPqvvAzBQ1WxOTh2ObVq8e5fIJb%2F5WTRv9OkVSSQ6cyJl3Wv3%2BxxuD8wf7KcgcBbxILpZaKIVqY7f4psgJokZEqZkoFoVBFHGxOJtPzrU1eAIU02tWQlkJm0%2BhBKDwvfnAKOtaqbO7Nl1KSZpGaDGx0tKWBhEV5r82NQ6KnychC8SeCb%2BW7DJSuTNkBjJHSqGtw4QI79yMd6lulVt%2BnRT5sCxhKqupzDUojcwyKy6rgY6nwHW34PyBOzLtiGggHBq2tXBx4CZbWpaGRd3pYc3iTGsitj8MdmJy8%2BS1u7XAivGbwSLYVj9%2BnQmWutsomZD6NyGOAtIU4W8gje%2FjSzFaczkNzZ%2B%2BB8kQZKIcWws7ZShFrG%2FVvqluJWIBDmK8irkNo51lVtNq2XQ51f4UQx01AsxOV%2FDLShGqMjnIx05GOdt9jHdjkvUEuLSk%2FAsWT4LATE%3D&Expires=1708043024"/>

# %%
# Call Amazon Rekognition to recognize celebrities in the image

customCelebrityResponse = rekognition.recognize_celebrities(
    Image={
        "S3Object": {
            "Bucket": bucket,
            "Name": customCelebrityImageName,
        }
    }
)

# %% [markdown]
# # Display Rekognition Response
# You will see Rekognition return an empty list for CelebrityFaces and
#
# UnrecognizedFaces list with unrecognized faces that were detected in the image.
#
# In the next module you will learn how to get custom-celebrity faces recognized.

# %%
display(customCelebrityResponse)
# Out:
# {'CelebrityFaces': [],
#  'UnrecognizedFaces': [{'BoundingBox': {'Width': 0.20627911388874054,
#     'Height': 0.3899897038936615,
#     'Left': 0.25654977560043335,
#     'Top': 0.4376027286052704},
#    'Confidence': 99.9995346069336,
#    'Landmarks': [{'Type': 'nose',
#      'X': 0.3577640652656555,
#      'Y': 0.6789306402206421},
#     {'Type': 'eyeLeft', 'X': 0.3156965374946594, 'Y': 0.5915206074714661},
#     {'Type': 'mouthLeft', 'X': 0.31642886996269226, 'Y': 0.7188389897346497},
#     {'Type': 'mouthRight', 'X': 0.3966156244277954, 'Y': 0.7275944948196411},
#     {'Type': 'eyeRight', 'X': 0.41131192445755005, 'Y': 0.601748526096344}],
#    'Pose': {'Roll': 3.4131057262420654,
#     'Yaw': -0.7230275273323059,
#     'Pitch': -5.356732368469238},
#    'Quality': {'Brightness': 59.37363052368164,
#     'Sharpness': 60.49041748046875},
#    'Emotions': [{'Type': 'HAPPY', 'Confidence': 93.38072204589844},
#     {'Type': 'SURPRISED', 'Confidence': 2.578389883041382},
#     {'Type': 'CONFUSED', 'Confidence': 1.3079657554626465},
#     {'Type': 'CALM', 'Confidence': 0.9100649356842041},
#     {'Type': 'DISGUSTED', 'Confidence': 0.7486628890037537},
#     {'Type': 'FEAR', 'Confidence': 0.6505882740020752},
#     {'Type': 'ANGRY', 'Confidence': 0.3111814558506012},
#     {'Type': 'SAD', 'Confidence': 0.11242809891700745}],
#    'Smile': {'Value': True, 'Confidence': 98.0884780883789}},
#   {'BoundingBox': {'Width': 0.10700850933790207,
#     'Height': 0.18312998116016388,
#     'Left': 0.5963900089263916,
#     'Top': 0.3054257035255432},
#    'Confidence': 99.993408203125,
#    'Landmarks': [{'Type': 'nose',
#      'X': 0.6505531072616577,
#      'Y': 0.3950507938861847},
#     {'Type': 'eyeLeft', 'X': 0.6298552751541138, 'Y': 0.3694416582584381},
#     {'Type': 'mouthLeft', 'X': 0.6306438446044922, 'Y': 0.4348967373371124},
#     {'Type': 'mouthRight', 'X': 0.6718012094497681, 'Y': 0.4370332658290863},
#     {'Type': 'eyeRight', 'X': 0.6792069673538208, 'Y': 0.37187132239341736}],
#    'Pose': {'Roll': 1.6133216619491577,
#     'Yaw': -2.779331684112549,
#     'Pitch': 20.762563705444336},
#    'Quality': {'Brightness': 65.66677856445312, 'Sharpness': 26.1773681640625},
#    'Emotions': [{'Type': 'CALM', 'Confidence': 96.20024108886719},
#     {'Type': 'HAPPY', 'Confidence': 3.423208713531494},
#     {'Type': 'DISGUSTED', 'Confidence': 0.129334956407547},
#     {'Type': 'SURPRISED', 'Confidence': 0.09065661579370499},
#     {'Type': 'ANGRY', 'Confidence': 0.07275458425283432},
#     {'Type': 'CONFUSED', 'Confidence': 0.053175825625658035},
#     {'Type': 'SAD', 'Confidence': 0.025662299245595932},
#     {'Type': 'FEAR', 'Confidence': 0.004965218249708414}],
#    'Smile': {'Value': False, 'Confidence': 86.04231262207031}}],
#  'ResponseMetadata': {'RequestId': '0be01e52-1a8c-4271-abf1-51dc86959f92',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '0be01e52-1a8c-4271-abf1-51dc86959f92',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '2296',
#    'date': 'Thu, 15 Feb 2024 23:23:44 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# # Show Image and Bounded Boxes around Detected Faces

# %%
cboxes = []
faces = customCelebrityResponse["UnrecognizedFaces"]
for face in faces:
    cboxes.append(("Unrecognized Face", face["BoundingBox"]))

drawBoundingBoxes(customCelebrityImageName, cboxes)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=288x216>

# %% [markdown]
# # Congratulations!
# You have successfully used Amazon Rekognition to identify celebrities in images an videos.
#
# # References
# - https://docs.aws.amazon.com/rekognition/latest/dg/celebrities.html
# - https://docs.aws.amazon.com/rekognition/latest/dg/API_RecognizeCelebrities.html
# - https://docs.aws.amazon.com/rekognition/latest/dg/API_StartCelebrityRecognition.html
# - https://docs.aws.amazon.com/rekognition/latest/dg/API_GetCelebrityRecognition.html

# %% [markdown]
# # Release Resources

# %%
# %%html
#
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>
# Out:
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>

# %%
# %%javascript
#
# try {
#     Jupyter.notebook.save_checkpoint();
#     Jupyter.notebook.session.delete();
# }
# catch(err) {
#     // NoOp
# }
